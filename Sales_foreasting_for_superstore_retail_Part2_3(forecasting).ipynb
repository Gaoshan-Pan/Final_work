# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaoshan-Pan/Final_work/blob/main/Sales_foreasting_for_superstore_retail_Part2_3(forecasting).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Time-Series Forecasting of Sales in the Retail Domain

# %%
# Install a binary compatible package with pmdarima
# !pip install "numpy<2.0" "pmdarima==2.0.3"  # 2.0.3 is the current stable and compiled version on PyPI
# Out:
# Collecting numpy<2.0
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 417.8 kB/s eta 0:00:00
# Collecting pmdarima==2.0.3
#   Downloading pmdarima-2.0.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (7.8 kB)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.11/dist-packages (from pmdarima==2.0.3) (1.5.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.11/dist-packages (from pmdarima==2.0.3) (3.0.12)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.11/dist-packages (from pmdarima==2.0.3) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.11/dist-packages (from pmdarima==2.0.3) (1.6.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from pmdarima==2.0.3) (1.15.3)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from pmdarima==2.0.3) (0.14.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from pmdarima==2.0.3) (2.4.0)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.11/dist-packages (from pmdarima==2.0.3) (75.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19->pmdarima==2.0.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19->pmdarima==2.0.3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19->pmdarima==2.0.3) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.22->pmdarima==2.0.3) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels>=0.13.2->pmdarima==2.0.3) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels>=0.13.2->pmdarima==2.0.3) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=0.19->pmdarima==2.0.3) (1.17.0)
# Downloading pmdarima-2.0.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 15.5 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 17.0 MB/s eta 0:00:00
# Installing collected packages: numpy, pmdarima
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4 pmdarima-2.0.3

# %% [markdown]
# # Restart the kernel and then run import

# %%
# All imports
import numpy as np
import pandas as pd
from math import sqrt
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import root_mean_squared_error
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pmdarima import auto_arima

# %% [markdown]
# ## Load dataset <a name="data_understanding__load_dataset" id="data_understanding__load_dataset"></a>

# %%
import kagglehub
rohitsahoo_sales_forecasting_path = kagglehub.dataset_download('rohitsahoo/sales-forecasting')

print('Import is completed.')
# Out:
# Import is completed.

# %%
# Load the dataset
df=pd.read_csv('/kaggle/input/sales-forecasting/train.csv')
# Link to Dataset on Kaggle: Superstore Sales Dataset: https://www.kaggle.com/datasets/rohitsahoo/sales-forecasting/

# %% [markdown]
# ## Follow the previous part1 and data pre-processing before sales forecasting

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
#  17  Sales          9800 non-null   float64
# dtypes: float64(2), int64(1), object(15)
# memory usage: 1.3+ MB
# None

# %%
# ── Missing-value summary ────────────────────────────────────────────────
total_na   = df.isna().sum().sum()
by_column  = df.isna().sum().sort_values(ascending=False)

print(f"Total missing values in entire DataFrame: {total_na}\n")
print("Missing values by column:")
display(by_column)          # In a notebook, displays a neat Series table
# Out:
# Total missing values in entire DataFrame: 11
#
# Missing values by column:
# Postal Code      11
# Row ID            0
# Order ID          0
# Product Name      0
# Sub-Category      0
# Category          0
# Product ID        0
# Region            0
# State             0
# City              0
# Country           0
# Segment           0
# Customer Name     0
# Customer ID       0
# Ship Mode         0
# Ship Date         0
# Order Date        0
# Sales             0
# dtype: int64

# %% [markdown]
# ## Handle with missing/null values and non-meaningful data

# %%
# ── Handle missing / null values ─────────────────────────────────────────────
# Only a tiny share of the dataset, we can safely remove those rows instead of imputing them.
df = df.dropna(subset=["Postal Code"])
df.shape
# ── Remove features that add no value or raise privacy concerns ──────────────
# 1. 'Row ID' is simply a unique identifier, so it does not contribute
#    useful information for analysis or modelling.
df.drop("Row ID", axis="columns", inplace=True)

# 2. 'Customer Name' is omitted to minimise the risk of exposing
#    personally identifiable information during processing.
df.drop("Customer Name", axis="columns", inplace=True)

# %% [markdown]
# ## Data conversion-Convert column data types

# %%
# 1. Parse the order date strings into true datetime objects.
df["Order Date"] = pd.to_datetime(df["Order Date"],
                                  format="%d/%m/%Y",   # adjust if needed
                                  errors="raise")       # stop if a value is malformed

# 2. Convert the shipping dates; treat any impossible values as missing.
df["Ship Date"] = pd.to_datetime(df["Ship Date"], errors="coerce")

# 3. Cast to a nullable integer so NAs are still allowed.
df["Postal Code"] = df["Postal Code"].astype("Int64")

# 4. Change string-like columns with a limited set of distinct values
#    to the 'category' dtype to save memory and speed up grouping.
cat_cols = [
    "Ship Mode", "Segment", "Country", "City",
    "State", "Region", "Category", "Sub-Category"
]

df[cat_cols] = df[cat_cols].astype("category")

# %%
# Convert all categorical features from object type to category type
df['Ship Mode'] = df['Ship Mode'].astype('category')
df['Segment'] = df['Segment'].astype('category')
df['Country'] = df['Country'].astype('category')
df['City'] = df['City'].astype('category')
df['State'] = df['State'].astype('category')
df['Region'] = df['Region'].astype('category')
df['Category'] = df['Category'].astype('category')
df['Sub-Category'] = df['Sub-Category'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9789 entries, 0 to 9799
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      9789 non-null   object
#  1   Order Date    9789 non-null   datetime64[ns]
#  2   Ship Date     3811 non-null   datetime64[ns]
#  3   Ship Mode     9789 non-null   category
#  4   Customer ID   9789 non-null   object
#  5   Segment       9789 non-null   category
#  6   Country       9789 non-null   category
#  7   City          9789 non-null   category
#  8   State         9789 non-null   category
#  9   Postal Code   9789 non-null   Int64
#  10  Region        9789 non-null   category
#  11  Product ID    9789 non-null   object
#  12  Category      9789 non-null   category
#  13  Sub-Category  9789 non-null   category
#  14  Product Name  9789 non-null   object
#  15  Sales         9789 non-null   float64
# dtypes: Int64(1), category(8), datetime64[ns](2), float64(1), object(4)
# memory usage: 807.0+ KB

# %% [markdown]
# ## Sort by Order Date in order to do sales forecasting

# %%
# Sort by Order Date
df.sort_values(by=['Order Date'], inplace=True)
df.head()
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 7980  CA-2015-103800 2015-01-03 2015-07-01  Standard Class    DP-13000
# 741   CA-2015-112326 2015-01-04 2015-08-01  Standard Class    PO-19195
# 740   CA-2015-112326 2015-01-04 2015-08-01  Standard Class    PO-19195
# 739   CA-2015-112326 2015-01-04 2015-08-01  Standard Class    PO-19195
# 1759  CA-2015-141817 2015-01-05 2015-12-01  Standard Class    MB-18085
#
#           Segment        Country          City         State  Postal Code  \
# 7980     Consumer  United States       Houston         Texas        77095
# 741   Home Office  United States    Naperville      Illinois        60540
# 740   Home Office  United States    Naperville      Illinois        60540
# 739   Home Office  United States    Naperville      Illinois        60540
# 1759     Consumer  United States  Philadelphia  Pennsylvania        19143
#
#        Region       Product ID         Category Sub-Category  \
# 7980  Central  OFF-PA-10000174  Office Supplies        Paper
# 741   Central  OFF-BI-10004094  Office Supplies      Binders
# 740   Central  OFF-ST-10002743  Office Supplies      Storage
# 739   Central  OFF-LA-10003223  Office Supplies       Labels
# 1759     East  OFF-AR-10003478  Office Supplies          Art
#
#                                            Product Name    Sales
# 7980  Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448
# 741          GBC Standard Plastic Binding Systems Combs    3.540
# 740                       SAFCO Boltless Steel Shelving  272.736
# 739                                           Avery 508   11.784
# 1759  Avery Hi-Liter EverBold Pen Style Fluorescent ...   19.536

# %% [markdown]
# From data decription before, we know this time line is from 2015-01-03 to 2018-12-30

# %%
# Convert Order Date to datetime
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True)

# Aggregate sales by day
daily_sales = df.groupby('Order Date')['Sales'].sum().reset_index()
daily_sales = daily_sales.set_index('Order Date')
daily_sales.plot(figsize=(12, 6))
plt.title("Daily Sales Trend")
plt.show()

# %%
# Resample to monthly sales
monthly_sales = daily_sales.resample('M').sum()
monthly_sales.plot(figsize=(12, 6))
plt.title("Monthly Sales Trend")
plt.show()
# Out:
# <ipython-input-12-9788b3f55dae>:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_sales = daily_sales.resample('M').sum()

# %% [markdown]
# # Part2-sales forecasting

# %% [markdown]
# ##Simple Chronological Split
# Training: Earliest 60-70% of dates
# (Discover long-term trends and patterns)
# ​​Validation​​: Subsequent 15-20% of dates (Affect hyperparameters and identify overfitting)
# ​​Testing​​: Remains 15-20% of dates (Last unbiased test, replicating real deployment scenario)

# %% [markdown]
# | Block          | Period                      | Length | Why it works                                                                                       |
# | -------------- | --------------------------- | ------ | -------------------------------------------------------------------------------------------------- |
# | **Train**      | 2015-01-31 → **2017-06-30** | 30 mo  | 2½ years gives the model two full seasonal cycles and plenty of data to learn the trend.           |
# | **Validation** | 2017-07-31 → **2018-06-30** | 12 mo  | Exactly one calendar year to tune hyper-parameters, so Christmas / New-Year peaks are represented. |
# | **Test**       | 2018-07-31 → **2018-12-31** | 6 mo   | A completely unseen half-year for the final score and charts.                                      |

# %% [markdown]
# YUanma

# %%
# Since this is a time-series forecasting problem, the data should be split by past dates to train on, and future dates to predict. So I will use data from the years 2015 to 2017 for training, and use the data of the year 2018 for validation and testing (6 months for each)
train_start = pd.to_datetime('2015-01-31')  #using the last date of the month, since the grouping will be done by month
train_end = pd.to_datetime('2017-6-30')
validate_start = pd.to_datetime('2017-07-31')
validate_end = pd.to_datetime('2018-06-30')
test_start = pd.to_datetime('2018-07-31')
test_end = pd.to_datetime('2018-12-31')

# %%
# Time series data must be structured into a sequence of input-output pairs for LSTM models in such a way that each input is a
# fixed-length window of consecutive time steps (e.g., 12 months) and its corresponding output is the subsequent immediate value
# in the sequence. This sliding window approach creates sets of training samples in which months 1-12 are employed for predicting
# month 13, months 2-13 for predicting month 14, etc., in order to allow the model to learn temporal relationships among rolling
# time frames. To improve efficiency, we create a reusable function that systematically produces these input-label pairs such that
# equal preprocessing is applied in both initial model training and subsequent model retraining sessions. This structured change preserves
# the temporal relations within the data while enabling the LSTM to effectively extract and use time-dependent trends towards accurate prediction.

def create_sequences_for_lstm(data, window_size):
    training_seq_series = []
    training_label_series = []
    for i in range(len(data) - window_size - 1):
        training_seq = data[i:(i + window_size)]
        training_label = data[i + window_size]
        training_seq_series.append(training_seq)
        training_label_series.append(training_label)
    return np.array(training_seq_series), np.array(training_label_series)

# This function splits the time series data into training, validation, and testing sets based on specified date ranges.
# It uses the sequenced inputs/labels and the original date column to calculate index-based slicing.

def split(date_column,
          sequencedX, sequencedY,
          train_start_date, train_end_date,
          validate_start_date, validate_end_date,
          test_start_date, test_end_date,
          window_size):

    training_size = int(np.sum((date_column >= train_start_date) & (date_column <= train_end_date)) - window_size - 1)
    validation_size = int(np.sum((date_column >= validate_start_date) & (date_column <= validate_end_date)))

    X_training = sequencedX[:training_size]
    y_training = sequencedY[:training_size]
    X_validation = sequencedX[training_size:training_size+validation_size]
    y_validation = sequencedY[training_size:training_size+validation_size]
    X_testing = sequencedX[training_size+validation_size:]
    y_testing = sequencedY[training_size+validation_size:]

    return X_training, y_training, X_validation, y_validation, X_testing, y_testing

# LSTM input format must be 3D: [samples, time steps, features]. This reshapes the data accordingly.
def reshape(X_training, X_validation, X_testing):
    X_training = np.reshape(X_training, (X_training.shape[0], X_training.shape[1], 1))
    X_validation = np.reshape(X_validation, (X_validation.shape[0], X_validation.shape[1], 1))
    X_testing = np.reshape(X_testing, (X_testing.shape[0], X_testing.shape[1], 1))

    return X_training, X_validation, X_testing

# Visualizes the training and validation loss across epochs for model performance monitoring.
def plot_training_validation_loss(model_history, round_number, title_override=None):
    plt.figure(figsize=(8, 5))
    plt.plot(model_history.history['loss'], label='Training Loss')
    plt.plot(model_history.history['val_loss'], label='Validation Loss')
    if title_override is not None:
        plt.title(title_override)
    else:
        plt.title('Round' + round_number + ': Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# Generates sales predictions on a given dataset, reverses the scaling to restore original values, and calculates RMSE.
def predict_sales(model, X_data, y_labels, scaler):
    predicted_sales = model.predict(X_data)
    unscaled_predictions = scaler.inverse_transform(predicted_sales)
    unscaled_labels = scaler.inverse_transform(y_labels.reshape(-1, 1))
    rmse = sqrt(root_mean_squared_error(unscaled_labels, unscaled_predictions))
    return unscaled_predictions, unscaled_labels, rmse

# This function plots original sales data alongside predicted values from training and validation phases to compare performance visually.
def plot_training_and_validation_time_series_lstm(dataframe, date_column_name, sales_column_name,
                                                predicted_sales_on_training, predicted_sales_on_validation,
                                                scaler, title):
    # Set custom style
    plt.style.use('ggplot')

    plt.figure(figsize=(15, 5), facecolor='#f5f5f5')

    # Create empty arrays for plotting
    training_plot_array = np.empty_like(dataframe[sales_column_name])
    training_plot_array[:] = np.nan
    training_plot_array[window:len(predicted_sales_on_training)+window] = predicted_sales_on_training.flatten()

    starting_index = len(predicted_sales_on_training) + window
    ending_index = starting_index + len(predicted_sales_on_validation)

    validation_plot_array = np.empty_like(dataframe[sales_column_name])
    validation_plot_array[:] = np.nan
    validation_plot_array[starting_index:ending_index] = predicted_sales_on_validation.flatten()

    # Plot with custom styling
    plt.plot(dataframe[date_column_name],
             scaler.inverse_transform(dataframe[[sales_column_name]]),
             color='#2c3e50',
             linewidth=2.5,
             linestyle='-',
             alpha=0.9,
             label="Original Data")

    plt.plot(dataframe[date_column_name],
             training_plot_array,
             color='#e74c3c',
             linewidth=2,
             linestyle='--',
             alpha=0.8,
             label="Training Predictions")

    plt.plot(dataframe[date_column_name],
             validation_plot_array,
             color='#27ae60',
             linewidth=2,
             linestyle='-.',
             alpha=0.8,
             label="Validation Predictions")

    # Customize plot appearance
    plt.title(title, pad=20, fontsize=14, fontweight='bold')
    plt.legend(framealpha=0.9, facecolor='white', edgecolor='#333333')
    plt.grid(True, linestyle=':', alpha=0.7)
    plt.gca().set_facecolor('#f9f9f9')

    plt.tight_layout()
    plt.show()


# # Displays predicted and actual sales on the test dataset along a date axis, with formatting options for tick labels and layout.
def plot_testing_time_series_lstm(dataframe, date_column_name,
                                predicted_sales_on_testing,
                                y_labels_on_testing,
                                testing_start_date,
                                title,
                                x_axis_ticks_obj,
                                x_axis_ticks_formatter,
                                x_axis_ticks_rotation_angle):

    plt.figure(figsize=(12, 6), facecolor='#f8f9fa')

    test_data = dataframe[dataframe[date_column_name] >= testing_start_date]

    plt.plot(test_data[date_column_name], y_labels_on_testing,
            color='#3498db', linewidth=2.5, alpha=0.9,
            label='Actual Sales', marker='o', markersize=4)

    plt.plot(test_data[date_column_name], predicted_sales_on_testing,
            color='#e74c3c', linewidth=2, linestyle='--',
            alpha=0.8, label='Predicted Sales', marker='^', markersize=5)

    plt.xlabel('Date', fontsize=12, labelpad=10)
    plt.ylabel('Sales', fontsize=12, labelpad=10)
    plt.gca().xaxis.set_major_locator(x_axis_ticks_obj)

    if x_axis_ticks_formatter is not None:
        plt.gca().xaxis.set_major_formatter(x_axis_ticks_formatter)

    plt.xticks(rotation=x_axis_ticks_rotation_angle, ha='right', fontsize=10)
    plt.yticks(fontsize=10)

    plt.title(title, pad=20, fontsize=14, fontweight='bold')
    plt.legend(framealpha=1, facecolor='white', edgecolor='#95a5a6',
              fontsize=10, frameon=True)

    plt.grid(True, linestyle=':', alpha=0.7)
    plt.tight_layout()
    plt.show()

# %%
# For time-series forecasting, only two columns are needed: Order Date and Sales.
df_round1 = df[['Order Date', 'Sales']].rename(columns={'Order Date': 'date', 'Sales': 'monthly_sales'})
df_round1['monthly_sales'] = df_round1['monthly_sales']

# %%
df_round1.head()
# Out:
#            date  monthly_sales
# 7980 2015-01-03         16.448
# 741  2015-01-04          3.540
# 740  2015-01-04        272.736
# 739  2015-01-04         11.784
# 1759 2015-01-05         19.536

# %%
# Index the dataframe by Order Date. This is needed to be able to resample (group) by the Order Date
df_round1.set_index('date', inplace = True)
df_round1.head()
# Out:
#             monthly_sales
# date
# 2015-01-03         16.448
# 2015-01-04          3.540
# 2015-01-04        272.736
# 2015-01-04         11.784
# 2015-01-05         19.536

# %%
# Group by monthly sales and aggregate by SUM
df_round1 = df_round1.resample('ME')['monthly_sales'].sum().reset_index()  # Note: "ME" stands for "Month End"
df_round1.head()
# Out:
#         date  monthly_sales
# 0 2015-01-31      14205.707
# 1 2015-02-28       4519.892
# 2 2015-03-31      55205.797
# 3 2015-04-30      27906.855
# 4 2015-05-31      23644.303

# %%
df_round1.tail()
# Out:
#          date  monthly_sales
# 43 2018-08-31     62837.8480
# 44 2018-09-30     86152.8880
# 45 2018-10-31     77448.1312
# 46 2018-11-30    117938.1550
# 47 2018-12-31     82825.3588

# %%
# Use MinMaxScaler to scale the Sales to a value between 0 and 1  (i.e. from 0% to 100%)
minMaxScaler1 = MinMaxScaler()
df_round1['monthly_sales'] = minMaxScaler1.fit_transform(df_round1[['monthly_sales']])
print(df_round1['monthly_sales'].min(), df_round1['monthly_sales'].max())
# Out:
# 0.0 0.9999999999999999

# %%
# Use the sequencer utility function to obtain data and labels (i.e. true values to use for supervised learning)
window = 12
X, y = create_sequences_for_lstm(df_round1['monthly_sales'], window)

# %%
# Split data into training, validation, and testing by the dates specified above. Start by flagging the respective rows with "True"
train_indices1 = (df_round1['date'] >= train_start) & (df_round1['date'] <= train_end)
validate_indices1 = (df_round1['date'] >= validate_start) & (df_round1['date'] <= validate_end)
test_indices1 = (df_round1['date'] >= test_start) & (df_round1['date'] <= test_end)

# %%
# Determine the size of each partition by counting how many rows were marked with True in the previous step
train_size1 = int(np.sum(train_indices1) - window - 1) #note: subtracting 12 because the first 12 months are the first chunk of training data, nothing came before them in the sequence. In other words, the labels start from month 13 onwards.
validate_size1 = int(np.sum(validate_indices1))
#test_size1 = int(np.sum(test_indices1))

# %%
# Do the actual splitting, as per the division specified above.
X_train = X[:train_size1]
y_train = y[:train_size1]
X_validate = X[train_size1:train_size1+validate_size1]
y_validate = y[train_size1:train_size1+validate_size1]
X_test = X[train_size1+validate_size1:]
y_test = y[train_size1+validate_size1:]

# %%
# LSTM requires the input to be shaped into a 3D format.
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_validate = np.reshape(X_validate, (X_validate.shape[0], X_validate.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
print(X_train.shape)
print(y_train.shape)
print(X_validate.shape)
print(y_validate.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (17, 12, 1)
# (17,)
# (12, 12, 1)
# (12,)
# (6, 12, 1)
# (6,)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.regularizers import l2

lstm_model_round1 = Sequential()
lstm_model_round1.add(LSTM(64, input_shape=(X_train.shape[1], 1), return_sequences=True, kernel_regularizer=l2(0.01)))
lstm_model_round1.add(Dropout(0.2))
lstm_model_round1.add(LSTM(64, return_sequences=False, kernel_regularizer=l2(0.01)))
lstm_model_round1.add(Dropout(0.2))
lstm_model_round1.add(Dense(1))  # Regression output

lstm_model_round1.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Show model summary
lstm_model_round1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 12, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 12, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 49,985 (195.25 KB)
#  Trainable params: 49,985 (195.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
epochs1 = 100
#epochs1 = 300 # trying an overly large number of epochs to forcibly see how/when early stopping will step in.
batch_size1 = 12
early_stopping_patience = 10
early_stopping = EarlyStopping(monitor='val_loss', mode='min', patience=early_stopping_patience, restore_best_weights=True, verbose=1)

history1 = lstm_model_round1.fit(X_train, y_train,
                                 epochs=epochs1,
                                 batch_size=batch_size1,
                                 validation_data=(X_validate, y_validate),
                                 callbacks=[early_stopping],
                                 verbose=1)
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 493ms/step - loss: 1.1540 - val_loss: 1.1366
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.0711 - val_loss: 1.0524
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.0194 - val_loss: 0.9880
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.9652 - val_loss: 0.9408
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.9282 - val_loss: 0.9015
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.8922 - val_loss: 0.8642
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.8518 - val_loss: 0.8288
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.8174 - val_loss: 0.7954
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.7831 - val_loss: 0.7635
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.7490 - val_loss: 0.7331
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.7161 - val_loss: 0.7044
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.6834 - val_loss: 0.6765
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.6544 - val_loss: 0.6500
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.6263 - val_loss: 0.6235
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.6014 - val_loss: 0.5962
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0281 - val_loss: 0.0545
# Epoch 98: early stopping
# Restoring model weights from the end of the best epoch: 88.

# %%
# Plot training and validation loss graph
plot_training_validation_loss(history1, '1')

# %%
# Predict Sales on TRAINING Data, then on VALIDATION Data, then on TEST Data

p_sales_training1, y_sales_training1, rmse_training1 = predict_sales(lstm_model_round1, X_train, y_train, minMaxScaler1)
p_sales_validation1, y_sales_validation1, rmse_validation1 = predict_sales(lstm_model_round1, X_validate, y_validate, minMaxScaler1)
p_sales_test1, y_sales_test1, rmse_test1 = predict_sales(lstm_model_round1, X_test, y_test, minMaxScaler1)

print()
print(f'RMSE score on TRAINING Data: {rmse_training1}')
print(f'RMSE score on VALIDATION Data: {rmse_validation1}')
print(f'RMSE score on TEST Data: {rmse_test1}')
print()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# RMSE score on TRAINING Data: 137.14008428317504
# RMSE score on VALIDATION Data: 146.0350447766772
# RMSE score on TEST Data: 181.04428023631547

# %%
# Compare the actual sales numbers with predicted ones
temp_peek_df1 = pd.DataFrame(np.concatenate((y_sales_test1, p_sales_test1), axis=1), columns=['Actual Sales', 'Predicted Sales'])
temp_peek_df1
# Out:
#    Actual Sales  Predicted Sales
# 0    48190.7277     48776.648438
# 1    44825.1040     49677.222656
# 2    62837.8480     50718.335938
# 3    86152.8880     52391.441406
# 4    77448.1312     51448.375000
# 5   117938.1550     51159.332031

# %%
# Plot the results of prediction on TRAINING data and VALIDATION data
title = 'Exp1: Monthly Sales Forecasting using LSTM on TRAINING & VALIDATION Data'
plot_training_and_validation_time_series_lstm(df_round1, 'date', 'monthly_sales', p_sales_training1, p_sales_validation1, minMaxScaler1, title)

# %%
# Plot the results of prediction on TEST data
title = 'Exp1: Monthly Sales Forecasting using LSTM on TEST Data'
plot_testing_time_series_lstm(df_round1, 'date', p_sales_test1, y_sales_test1, test_start, title, mdates.MonthLocator(), mdates.DateFormatter('%b %Y'), 45)
# Note: it may appear that the months are starting from August, but that's because the dates are at the end of each month, so basically 2018-07-31 appears as if it is 2018-08-01, but if we closely examine the graph we'll notice that the line starts at a point that is slightly before the label of Aug2018 (i.e. the line starts at the last day of July).

# %% [markdown]
#  predict weekly sales instead of monthR3

# %%
df_round3 = df[['Order Date', 'Sales']]
df_round3 = df_round3.rename(columns={'Order Date': 'date', 'Sales': 'weekly_sales'})
df_round3.set_index('date', inplace = True)

# Group by weekly sales, and aggregate by SUM
df_round3 = df_round3.resample('W')['weekly_sales'].sum().reset_index()
df_round3.shape
# Out:
# (209, 2)

# %% [markdown]
# To maintains uniform weekly granularity for aggregations (e.g., weekly sales sums). And to prevent models from misinterpreting partial weeks as outliers or anomalies.
#
# ​SO, ​remove incomplete weeks​​ from the dataset

# %%
df_round3.drop(df_round3[df_round3['date'] <= '2015-01-04'].index, inplace=True)
df_round3.drop(df_round3[df_round3['date'] >= '2018-12-31'].index, inplace=True)
df_round3.shape
# Out:
# (208, 2)

# %%
minMaxScaler3 = MinMaxScaler()
df_round3['weekly_sales'] = minMaxScaler3.fit_transform(df_round3[['weekly_sales']])

window = 52
X3, y3 = create_sequences_for_lstm(df_round3['weekly_sales'], window)

# %% [markdown]
# Split the Data by Weeks. Second, Reshape for LSTM Input​, so convert the data into a ​​3D structure​​ ([samples, timesteps, features]) required for LSTM training.

# %%
train_start3 = pd.to_datetime('2015-01-11')
train_end3 = pd.to_datetime('2017-12-31')
validate_start3 = pd.to_datetime('2018-01-07')
validate_end3 = pd.to_datetime('2018-07-01')
test_start3 = pd.to_datetime('2018-07-08')
test_end3 = pd.to_datetime('2018-12-30')

X_train3, y_train3, X_validate3, y_validate3, X_test3, y_test3 = split(df_round3['date'], X3, y3, train_start3, train_end3, validate_start3, validate_end3, test_start3, test_end3, window)

X_train3, X_validate3, X_test3 = reshape(X_train3, X_validate3, X_test3)

# %% [markdown]
# Same model as previous

# %%
lstm_model_round3 = Sequential()
lstm_model_round3.add(LSTM(64, input_shape=(X_train.shape[1], 1), return_sequences=True, kernel_regularizer=l2(0.01)))
lstm_model_round3.add(Dropout(0.2))
lstm_model_round3.add(LSTM(64, return_sequences=False, kernel_regularizer=l2(0.01)))
lstm_model_round3.add(Dropout(0.2))
lstm_model_round3.add(Dense(1))  # Regression output

lstm_model_round3.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Train the model
epochs3 = 100
batch_size3 = 12
early_stopping_patience3 = 10
early_stopping3 = EarlyStopping(monitor='val_loss', mode='min', patience=early_stopping_patience3, restore_best_weights=True, verbose=1)

history3 = lstm_model_round3.fit(X_train3, y_train3,
                                 epochs=epochs3,
                                 batch_size=batch_size3,
                                 validation_data=(X_validate3, y_validate3),
                                 callbacks=[early_stopping3],
                                 verbose=1)
# Out:
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 1.0554 - val_loss: 0.9007
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.8514 - val_loss: 0.7239
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.7051 - val_loss: 0.5916
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.5657 - val_loss: 0.4795
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.4608 - val_loss: 0.3848
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.3745 - val_loss: 0.3127
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.3019 - val_loss: 0.2503
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.2456 - val_loss: 0.2013
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.1976 - val_loss: 0.1634
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1594 - val_loss: 0.1309
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1322 - val_loss: 0.1068
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1052 - val_loss: 0.0885
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0882 - val_loss: 0.0725
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0800 - val_loss: 0.0604
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0620 - val_loss: 0.0515
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0552 - val_loss: 0.0456
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0506 - val_loss: 0.0390
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0433 - val_loss: 0.0363
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0432 - val_loss: 0.0320
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0383 - val_loss: 0.0307
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0405 - val_loss: 0.0279
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0339 - val_loss: 0.0271
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0316 - val_loss: 0.0257
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0328 - val_loss: 0.0249
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0340 - val_loss: 0.0248
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0408 - val_loss: 0.0238
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0305 - val_loss: 0.0234
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0319 - val_loss: 0.0244
# Epoch 29/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0305 - val_loss: 0.0229
# Epoch 30/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0374 - val_loss: 0.0233
# Epoch 31/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0290 - val_loss: 0.0226
# Epoch 32/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0289 - val_loss: 0.0237
# Epoch 33/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0297 - val_loss: 0.0224
# Epoch 34/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0288 - val_loss: 0.0223
# Epoch 35/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0367 - val_loss: 0.0227
# Epoch 36/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0305 - val_loss: 0.0222
# Epoch 37/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0357 - val_loss: 0.0221
# Epoch 38/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0297 - val_loss: 0.0220
# Epoch 39/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0343 - val_loss: 0.0220
# Epoch 40/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0298 - val_loss: 0.0220
# Epoch 41/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0310 - val_loss: 0.0221
# Epoch 42/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0343 - val_loss: 0.0220
# Epoch 43/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0275 - val_loss: 0.0230
# Epoch 44/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0342 - val_loss: 0.0237
# Epoch 45/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0297 - val_loss: 0.0218
# Epoch 46/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0344 - val_loss: 0.0217
# Epoch 47/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0309 - val_loss: 0.0217
# Epoch 48/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0370 - val_loss: 0.0220
# Epoch 49/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0308 - val_loss: 0.0217
# Epoch 50/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0294 - val_loss: 0.0218
# Epoch 51/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0308 - val_loss: 0.0221
# Epoch 52/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0309 - val_loss: 0.0219
# Epoch 53/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0252 - val_loss: 0.0222
# Epoch 54/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0323 - val_loss: 0.0228
# Epoch 55/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0270 - val_loss: 0.0256
# Epoch 56/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0306 - val_loss: 0.0246
# Epoch 57/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0275 - val_loss: 0.0223
# Epoch 58/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0320 - val_loss: 0.0226
# Epoch 59/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0301 - val_loss: 0.0236
# Epoch 59: early stopping
# Restoring model weights from the end of the best epoch: 49.

# %%
# Plot training and validation loss graph
plot_training_validation_loss(history3, '3')

# %% [markdown]
# delete exp2

# %%
p_sales_training3, y_sales_training3, rmse_training3 = predict_sales(lstm_model_round3, X_train3, y_train3, minMaxScaler3)
p_sales_validation3, y_sales_validation3, rmse_validation3 = predict_sales(lstm_model_round3, X_validate3, y_validate3, minMaxScaler3)
p_sales_test3, y_sales_test3, rmse_test3 = predict_sales(lstm_model_round3, X_test3, y_test3, minMaxScaler3)

print()
print(f'Exp3: RMSE score on Training Data: {rmse_training3}')
print(f'Exp3: RMSE score on Val Data: {rmse_validation3}')
print(f'Exp3: RMSE score on Test Data: {rmse_test3}')
print()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Exp3: RMSE score on Training Data: 79.06423561700734
# Exp3: RMSE score on Val Data: 72.97540912389363
# Exp3: RMSE score on Test Data: 99.9376109411021

# %%
temp_peek_df3 = pd.DataFrame(np.concatenate((y_sales_test3, p_sales_test3), axis=1), columns=['Actual Sales', 'Predicted Sales'])
temp_peek_df3
# Out:
#     Actual Sales  Predicted Sales
# 0      6318.9355      9740.757812
# 1     17261.1922      9792.525391
# 2     11589.8420      9845.823242
# 3      9998.8410      9885.208008
# 4     10896.3050      9919.049805
# 5      9618.8820      9937.595703
# 6      5205.6280      9911.328125
# 7     11128.5300      9895.110352
# 8     22222.5540      9966.811523
# 9     15330.0720     10053.652344
# 10    20946.6120     10186.922852
# 11    17672.0480     10325.264648
# 12    20166.2010     10478.384766
# 13    26104.4330     10677.947266
# 14    12296.0620     10803.067383
# 15    21535.5940     10931.774414
# 16    16509.8310     11018.647461
# 17    13270.8182     11045.593750
# 18    21535.2700     11084.038086
# 19    29017.4670     11184.981445
# 20    20015.5500     11263.037109
# 21    30572.4470     11393.784180
# 22    22212.7690     11499.580078
# 23    35998.9000     11678.553711
# 24    21332.2110     11798.625000
# 25    11542.8340     11792.720703

# %%
# Plot the results of prediction on TRAINING data and VALIDATION data
title = 'Exp3: Weekly Sales Forecasting using LSTM on TRAINING & VALIDATION Data (WEEKLY Sales)'
plot_training_and_validation_time_series_lstm(df_round3, 'date', 'weekly_sales', p_sales_training3, p_sales_validation3, minMaxScaler3, title)

# %%
# Plot the results of prediction on TEST data
title = 'Exp3: Weekly Sales Forecasting using LSTM on TEST Data (WEEKLY Sales)'
plot_testing_time_series_lstm(df_round3, 'date', p_sales_test3, y_sales_test3, test_start3, title, mdates.WeekdayLocator(), None, 90)

# %% [markdown]
# **conclusion:**
#
# At this phase of the analysis, I played around with whether forecast at a weekly level of sales data (as opposed to monthly) would more closely align with the forecasts. I hypothesized that additional granularity (weekly totals) might be capable of detecting more nuanced trends or seasonal influences that a monthly aggregate won't be capable of detecting.
#
# **Key Observations from the Experiment:**
# 1. Weekly vs. Monthly Aggregation:
# • Weekly Sales Data: Provided more data points (52 weeks/year compared to 12 months/year), potentially revealing short-term trends.
#
#    • Monthly Sales Data: Smoothing out noise but potentially obscuring abrupt changes (e.g., holiday spikes, promotion impact).
#
# 2. Model Performance:
#    • Despite the greater granularity, forecasts were still inaccurate, with variances similar to or worse than monthly totals.
#
# • Possible explanations:
#
#  ◦ Noise Amplification: Weekly data imposed volatility (e.g., random demand, outliers) without adding useful signal.
#
#  ◦ Not Enough Historical Context: The model may need additional long-term trends (e.g., annual cycles) captured by monthlies.
#
# ◦ Model Constraints: The chosen model (for instance, LSTM, ARIMA) might struggle with high-frequency noise or be hyperparameter-sensitive.
#
# 3. Graphical Evidence:
#    • Plots for predictions did not reveal any significant improvement with respect to actual sales.
#
#    • Errors (for example, MAE, RMSE) were comparable or even higher than monthly outcomes, with no advantage for weekly splits.
#
#
# **Next Steps:**
# Since aggregation at the week level did not yield better accuracy, we'll go back to monthly sales data and explore other strategies, including:
# • Feature Engineering: Include external variables (e.g., promotions, holidays, economic indicators).
#
# • Model Tweaks:
#
#   • Compare varied architectures (e.g., Prophet, XGBoost time series).
#
#   • Hyperparameter tuning (e.g., window size, lag features).
#
# • Data Transformation:
#
# • Utilize differencing or scaling logs to stabilize variance.
#
# • Utilize rolling statistics (e.g., moving averages for 3 months) as inputs.
#
# • Hybrid Methods: Combine monthly trends with weekly/daily data for hierarchical forecasting.
#
# **Conclusion:**
# While weekly data offered no short-term benefit, this test points to the worth of experimenting with granularity levels and calibrating them in accordance with the model's capability. Future research will focus on refining the monthly method while eliminating root noise and trend extraction.
#
# ---
#
# **Key Takeaways:**
# • Granularity ≠ Accuracy: More data is not always better; it depends on the problem context.
#
# • Diagnostic Checks: Always depict predictions and estimate errors (e.g., residuals analysis).
#
# • Iterative Process: Every iteration narrows the list of possible strategies—here, month aggregation stays at default.

# %% [markdown]
# R4

# %%
#For detailed explanation of the steps, see detailed comments on code cells in Round 1
df_round4 = df[['Order Date', 'Sales']]
df_round4 = df_round4.rename(columns={'Order Date': 'date', 'Sales': 'monthly_sales'})
df_round4.set_index('date', inplace = True)


df_round4 = df_round4.resample('ME')['monthly_sales'].sum().reset_index()
df_round4.head()
# Out:
#         date  monthly_sales
# 0 2015-01-31      14205.707
# 1 2015-02-28       4519.892
# 2 2015-03-31      55205.797
# 3 2015-04-30      27906.855
# 4 2015-05-31      23644.303

# %%
minMaxScaler4 = MinMaxScaler()
df_round4['monthly_sales'] = minMaxScaler4.fit_transform(df_round4[['monthly_sales']])

window = 12
X4, y4 = create_sequences_for_lstm(df_round4['monthly_sales'], window)

# %%
# Data splition
X_train4, y_train4, X_validate4, y_validate4, X_test4, y_test4 = split(df_round4['date'], X4, y4, train_start, train_end, validate_start, validate_end, test_start, test_end, window)

# convert it to 3D
X_train4, X_validate4, X_test4 = reshape(X_train4, X_validate4, X_test4)

# %% [markdown]
# New network architecture

# %%
num_neurons4_layer1 = 100
num_neurons4_layer2 = 60
num_neurons4_layer3 = 30
num_neurons4_layer4 = 10
regularization = l2
regularization_factor = 0.01

lstm_model_round4 = Sequential()
lstm_model_round4.add(LSTM(num_neurons4_layer1,
                           input_shape=(X_train4.shape[1], 1),
                           return_sequences=True,
                           kernel_regularizer=regularization(regularization_factor)))
lstm_model_round4.add(LSTM(num_neurons4_layer2,
                           return_sequences=True,
                           kernel_regularizer=regularization(regularization_factor)))
lstm_model_round4.add(LSTM(num_neurons4_layer3,
                           return_sequences=True,
                           kernel_regularizer=regularization(regularization_factor)))
lstm_model_round4.add(LSTM(num_neurons4_layer4, kernel_regularizer=regularization(regularization_factor)))
lstm_model_round4.add(Dense(1))
lstm_model_round4.compile(optimizer='adam', loss='mean_squared_error')
lstm_model_round4.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                   │ (None, 12, 100)        │        40,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 12, 60)         │        38,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_6 (LSTM)                   │ (None, 12, 30)         │        10,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 10)             │         1,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 92,011 (359.42 KB)
#  Trainable params: 92,011 (359.42 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
epochs4 = 300
batch_size4 = 12
early_stopping_patience4 = 10
early_stopping4 = EarlyStopping(monitor='val_loss', mode='min', patience=early_stopping_patience4, restore_best_weights=True, verbose=1)

history4 = lstm_model_round4.fit(X_train4, y_train4,
                                 epochs=epochs4,
                                 batch_size=batch_size4,
                                 validation_data=(X_validate4, y_validate4),
                                 callbacks=[early_stopping4],
                                 verbose=1)
# Out:
# Epoch 1/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 835ms/step - loss: 2.6848 - val_loss: 2.6559
# Epoch 2/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 2.5545 - val_loss: 2.5302
# Epoch 3/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 2.4454 - val_loss: 2.4089
# Epoch 4/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 2.3403 - val_loss: 2.2916
# Epoch 5/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 2.2348 - val_loss: 2.1808
# Epoch 6/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 2.1464 - val_loss: 2.0828
# Epoch 7/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 2.0632 - val_loss: 1.9990
# Epoch 8/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 1.9863 - val_loss: 1.9221
# Epoch 9/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 1.9083 - val_loss: 1.8500
# Epoch 10/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 1.8314 - val_loss: 1.7819
# Epoch 11/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 1.7575 - val_loss: 1.7182
# Epoch 12/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 1.6904 - val_loss: 1.6570
# Epoch 13/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.6253 - val_loss: 1.5974
# Epoch 14/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 1.5592 - val_loss: 1.5378
# Epoch 15/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 1.5019 - val_loss: 1.4784
# Epoch 16/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.4417 - val_loss: 1.4194
# Epoch 17/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 1.3801 - val_loss: 1.3608
# Epoch 18/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.3290 - val_loss: 1.3032
# Epoch 19/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.2735 - val_loss: 1.2483
# Epoch 20/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 1.2213 - val_loss: 1.1965
# Epoch 21/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 1.1750 - val_loss: 1.1476
# Epoch 22/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.1274 - val_loss: 1.1024
# Epoch 23/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.0791 - val_loss: 1.0600
# Epoch 24/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 1.0365 - val_loss: 1.0186
# Epoch 25/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.9950 - val_loss: 0.9792
# Epoch 26/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.9563 - val_loss: 0.9419
# Epoch 27/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.9195 - val_loss: 0.9075
# Epoch 28/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.8831 - val_loss: 0.8757
# Epoch 29/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.8448 - val_loss: 0.8440
# Epoch 30/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.8137 - val_loss: 0.8122
# Epoch 31/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.7832 - val_loss: 0.7811
# Epoch 32/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.7507 - val_loss: 0.7506
# Epoch 33/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.7210 - val_loss: 0.7200
# Epoch 34/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.6918 - val_loss: 0.6899
# Epoch 35/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.6619 - val_loss: 0.6605
# Epoch 36/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.6399 - val_loss: 0.6328
# Epoch 37/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.6139 - val_loss: 0.6086
# Epoch 38/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.5890 - val_loss: 0.5866
# Epoch 39/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.5648 - val_loss: 0.5647
# Epoch 40/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.5452 - val_loss: 0.5427
# Epoch 41/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.5245 - val_loss: 0.5223
# Epoch 42/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.5048 - val_loss: 0.5040
# Epoch 43/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.4822 - val_loss: 0.4867
# Epoch 44/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.4638 - val_loss: 0.4690
# Epoch 45/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.4483 - val_loss: 0.4524
# Epoch 46/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.4296 - val_loss: 0.4361
# Epoch 47/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.4142 - val_loss: 0.4214
# Epoch 48/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.3993 - val_loss: 0.4082
# Epoch 49/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.3845 - val_loss: 0.3947
# Epoch 50/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.3674 - val_loss: 0.3800
# Epoch 51/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.3552 - val_loss: 0.3653
# Epoch 52/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0
# Epoch 144/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 0.0325 - val_loss: 0.0543
# Epoch 145/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0287 - val_loss: 0.0459
# Epoch 146/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 0.0301 - val_loss: 0.0407
# Epoch 147/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0279 - val_loss: 0.0430
# Epoch 148/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0268 - val_loss: 0.0475
# Epoch 149/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0249 - val_loss: 0.0456
# Epoch 150/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.0274 - val_loss: 0.0410
# Epoch 151/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0257 - val_loss: 0.0388
# Epoch 152/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0272 - val_loss: 0.0390
# Epoch 153/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0266 - val_loss: 0.0437
# Epoch 154/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0245 - val_loss: 0.0419
# Epoch 155/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0248 - val_loss: 0.0396
# Epoch 156/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0250 - val_loss: 0.0370
# Epoch 157/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.0257 - val_loss: 0.0391
# Epoch 158/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0245 - val_loss: 0.0445
# Epoch 159/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0255 - val_loss: 0.0474
# Epoch 160/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0264 - val_loss: 0.0461
# Epoch 161/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0238 - val_loss: 0.0395
# Epoch 162/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0223 - val_loss: 0.0357
# Epoch 163/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0248 - val_loss: 0.0355
# Epoch 164/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.0237 - val_loss: 0.0398
# Epoch 165/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0230 - val_loss: 0.0457
# Epoch 166/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0235 - val_loss: 0.0442
# Epoch 167/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0241 - val_loss: 0.0369
# Epoch 168/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0208 - val_loss: 0.0346
# Epoch 169/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0229 - val_loss: 0.0349
# Epoch 170/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0222 - val_loss: 0.0378
# Epoch 171/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0215 - val_loss: 0.0426
# Epoch 172/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0213 - val_loss: 0.0413
# Epoch 173/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0225 - val_loss: 0.0338
# Epoch 174/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0202 - val_loss: 0.0340
# Epoch 175/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0218 - val_loss: 0.0359
# Epoch 176/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0207 - val_loss: 0.0368
# Epoch 177/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0205 - val_loss: 0.0371
# Epoch 178/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0200 - val_loss: 0.0373
# Epoch 179/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0204 - val_loss: 0.0372
# Epoch 180/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0209 - val_loss: 0.0387
# Epoch 181/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0193 - val_loss: 0.0368
# Epoch 182/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0200 - val_loss: 0.0341
# Epoch 183/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0191 - val_loss: 0.0333
# Epoch 184/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0200 - val_loss: 0.0365
# Epoch 185/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0190 - val_loss: 0.0403
# Epoch 186/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0200 - val_loss: 0.0362
# Epoch 187/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0183 - val_loss: 0.0327
# Epoch 188/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0200 - val_loss: 0.0340
# Epoch 189/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0193 - val_loss: 0.0489
# Epoch 190/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0224 - val_loss: 0.0535
# Epoch 191/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0219 - val_loss: 0.0390
# Epoch 192/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0190 - val_loss: 0.0316
# Epoch 193/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0220 - val_loss: 0.0317
# Epoch 194/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0211 - val_loss: 0.0370
# Epoch 195/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0198 - val_loss: 0.0398
# Epoch 196/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0209 - val_loss: 0.0387
# Epoch 197/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0174 - val_loss: 0.0343
# Epoch 198/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0189 - val_loss: 0.0323
# Epoch 199/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0189 - val_loss: 0.0333
# Epoch 200/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0187 - val_loss: 0.0355
# Epoch 201/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0186 - val_loss: 0.0374
# Epoch 202/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0192 - val_loss: 0.0392
# Epoch 202: early stopping
# Restoring model weights from the end of the best epoch: 192.

# %%
# Plot training and validation loss graph
plot_training_validation_loss(history4, '4')

# %%
# Predict Sales on TRAINING Data, then on VALIDATION Data, then on TEST Data

p_sales_training4, y_sales_training4, rmse_training4 = predict_sales(lstm_model_round4, X_train4, y_train4, minMaxScaler4)
p_sales_validation4, y_sales_validation4, rmse_validation4 = predict_sales(lstm_model_round4, X_validate4, y_validate4, minMaxScaler4)
p_sales_test4, y_sales_test4, rmse_test4 = predict_sales(lstm_model_round4, X_test4, y_test4, minMaxScaler4)

print()
print(f'Exp4: RMSE score on TRAINING Data: {rmse_training4}')
print(f'Exp4: RMSE score on VALIDATION Data: {rmse_validation4}')
print(f'Exp4: RMSE score on TEST Data: {rmse_test4}')
print()
# Out:
# WARNING:tensorflow:5 out of the last 10 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x79e3a7cf34c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 550ms/step
# WARNING:tensorflow:6 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x79e3a7cf34c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 706ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#
# Exp4: RMSE score on TRAINING Data: 119.17103223043667
# Exp4: RMSE score on VALIDATION Data: 135.28554838882937
# Exp4: RMSE score on TEST Data: 166.5832995158712

# %%
# Plot the results of prediction on TRAINING data and VALIDATION data
title = 'Exp4: Monthly Sales Forecasting using LSTM on TRAINING & VALIDATION Data (diff network architecture)'
plot_training_and_validation_time_series_lstm(df_round4, 'date', 'monthly_sales', p_sales_training4, p_sales_validation4, minMaxScaler4, title)

# %%
# Plot the results of prediction on TEST data
title = 'Exp4: Monthly Sales Forecasting using LSTM on TEST Data (diff network architecture)'
plot_testing_time_series_lstm(df_round4, 'date', p_sales_test4, y_sales_test4, test_start, title, mdates.MonthLocator(), mdates.DateFormatter('%b %Y'), 45)

# %% [markdown]
# ​​Detailed Analysis of Architectural Improvements and Their Impact on Model Performance​.
# This experimental stage focused heavily on ​​optimizing the LSTM network architecture​​ and ​​training hyperparameters​​ to achieve better prediction accuracy. The improvements were:
#
# ​​1. Architectural Refinements​​
# ​​(a) Depth Increase in the Network
#
# ​​Previous Architecture:​​ 2 LSTM layers
# ​​New Architecture:​​ 4 LSTM layers
# ​​Reason:
# More capable networks can resolve more complex temporal patterns between sequential data.
# More layers facilitate hierarchical feature extraction—lower layers detect short-term patterns, and higher layers learn long-term trends.
# (b) Neuron Varying Number per Layer
#
# Neuron Distribution: 100 → 60 → 30 → 10
# Reasoning:
# Progressively lower-dimensional representation of temporal features is enabled by a decreasing neuron number that eliminates noise and retains informative patterns.
# The architecture is similar to an autoencoder-like method, where generalization is supported through dimensionality reduction.
# 2. Modifications on the Training Process
# Epochs from 50 → 300
# Effect:
# Lower loss values were achieved by the model with each epoch, indicating better optimization.
# More training allowed the network to fine-tune weights more effectively, reducing prediction errors.
# ​​3. Performance Evaluation​​
# ​​(a) Trend Alignment Improvement​
#
# ​​Graphical Analysis:
# The ​​predicted trend (orange line)​​ is now more in sync with the ​​actual sales (blue line)​​, particularly in detecting ​​peaks and troughs​​.
# Although ​​absolute value accuracy​​ leaves much to be desired, the model better captures ​​when sales go up or down​​, which is priceless for decision-making.
# ​​(b) Loss Reduction​
#
# ​​Training Dynamics:
# Loss curve showed consistent decreasing through epochs, that the model wasn't overfitting but learning instead.
# No flattening revealed additional training (e.g., 300+) to yield additional gains.
# ​​4. Key Takeaways & What's Next​​
# ​​(a) Keep Current Architecture​
#
# The ​​4-layer LSTM with diminishing neurons​​ was superior to the previous 2-layer setup.
# Future experimentation may try:
# ​​Even deeper networks​​ (e.g., 5-6 layers) with skip connections to avoid vanishing gradients.
# ​​Alternative neuron distributions​​ (e.g., 128 → 64 → 32 → 16) for increased capacity.
# ​​(b) Explore Other Enhancements___
#
# ​​Data Preparation:__
# Try alternative ​​lag windows​​ (e.g., 6-month versus 12-month lookbacks).
# Add ​​external variables​​ (e.g., promotions, holidays) to provide more context.
# ​​Regularization:__
# Add ​​dropout layers​​ or ​​L2 regularization​​ to prevent overfitting in deeper networks.
# ​​Alternative Models:__
# Benchmark against ​​Transformer-based​​ models (e.g., Temporal Fusion Transformer) for potential gains.
# ​​Conclusion__()
# This version demonstrated that ​​increased model complexity​​ (more layers, neurons, and epochs) significantly improved trend prediction, although overall absolute value prediction still needs to be perfected. Future versions will ​​utilize the effective architectural changes​​ while exploring complementary improvements in data engineering and model tuning.

# %% [markdown]
# ##Experiment Design​​ 5
#
# In this version, we introduce a ​​strategic improvement​​ to our forecasting methodology by adding ​​category-level analysis​​. Rather than ingesting all product sales combined, we divide the data into three categories:
#
# ​​Furniture​​
# ​​Office Supplies​​
# ​​Technology​​
# This allows the model to ​​learn separate demand patterns​​ for each product type, which can improve forecast precision by picking up on category-specific trends and seasonality.

# %%
# Group by CATEGORY and by MONTHLY sales
df_round5 = df[['Order Date', 'Category', 'Sales']]
df_round5.set_index('Order Date', inplace = True)
df_round5 = df_round5.groupby(['Order Date','Category'], observed=False)['Sales'].sum().reset_index()
df_round5 = df_round5.set_index(['Order Date', 'Category']).unstack('Category').fillna(0)
df_round5.columns = df_round5.columns.levels[1].rename(None)
df_round5 = df_round5.resample('ME').sum().reset_index()

# %%
# break the data into 3 separate dataframes, one for each category of sales
df_round5_f = df_round5[['Order Date', 'Furniture']]
df_round5_s = df_round5[['Order Date', 'Office Supplies']]
df_round5_t = df_round5[['Order Date', 'Technology']]

# %%
minMaxScaler5_f = MinMaxScaler()
minMaxScaler5_s = MinMaxScaler()
minMaxScaler5_t = MinMaxScaler()

df_round5_f['Furniture'] = minMaxScaler5_f.fit_transform(df_round5_f[['Furniture']])
df_round5_s['Office Supplies'] = minMaxScaler5_s.fit_transform(df_round5_s[['Office Supplies']])
df_round5_t['Technology'] = minMaxScaler5_t.fit_transform(df_round5_t[['Technology']])

window = 12
X5_f, y5_f = create_sequences_for_lstm(df_round5_f['Furniture'], window)
X5_s, y5_s = create_sequences_for_lstm(df_round5_s['Office Supplies'], window)
X5_t, y5_t = create_sequences_for_lstm(df_round5_t['Technology'], window)
# Out:
# <ipython-input-57-a3b4094031aa>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_round5_f['Furniture'] = minMaxScaler5_f.fit_transform(df_round5_f[['Furniture']])
# <ipython-input-57-a3b4094031aa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_round5_s['Office Supplies'] = minMaxScaler5_s.fit_transform(df_round5_s[['Office Supplies']])
# <ipython-input-57-a3b4094031aa>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_round5_t['Technology'] = minMaxScaler5_t.fit_transform(df_round5_t[['Technology']])

# %%
# Split data into training, validation, and testing by the dates specified earlier.
X_train5_f, y_train5_f, X_validate5_f, y_validate5_f, X_test5_f, y_test5_f = split(df_round5_f['Order Date'], X5_f, y5_f, train_start, train_end, validate_start, validate_end, test_start, test_end, window)
X_train5_s, y_train5_s, X_validate5_s, y_validate5_s, X_test5_s, y_test5_s = split(df_round5_s['Order Date'], X5_s, y5_s, train_start, train_end, validate_start, validate_end, test_start, test_end, window)
X_train5_t, y_train5_t, X_validate5_t, y_validate5_t, X_test5_t, y_test5_t = split(df_round5_t['Order Date'], X5_t, y5_t, train_start, train_end, validate_start, validate_end, test_start, test_end, window)

# reshape the input arrays
X_train5_f, X_validate5_f, X_test5_f = reshape(X_train5_f, X_validate5_f, X_test5_f)
X_train5_s, X_validate5_s, X_test5_s = reshape(X_train5_s, X_validate5_s, X_test5_s)
X_train5_t, X_validate5_t, X_test5_t = reshape(X_train5_t, X_validate5_t, X_test5_t)

# %% [markdown]
# New hyperparameters

# %%
# Build LSTM model for Furniture category
num_neurons5_layer1 = 100
num_neurons5_layer2 = 60
num_neurons5_layer3 = 30
num_neurons5_layer4 = 10
regularization = l2
regularization_factor = 0.01

lstm_model_round5_f = Sequential()
lstm_model_round5_f.add(LSTM(num_neurons5_layer1,
                           input_shape=(X_train5_f.shape[1], 1),
                           return_sequences=True,
                           kernel_regularizer=regularization(regularization_factor)))
lstm_model_round5_f.add(LSTM(num_neurons5_layer2,
                           return_sequences=True,
                           kernel_regularizer=regularization(regularization_factor)))
lstm_model_round5_f.add(LSTM(num_neurons5_layer3,
                           return_sequences=True,
                           kernel_regularizer=regularization(regularization_factor)))
lstm_model_round5_f.add(LSTM(num_neurons5_layer4, kernel_regularizer=regularization(regularization_factor)))
lstm_model_round5_f.add(Dense(1))
lstm_model_round5_f.compile(optimizer='adam', loss='mean_squared_error')
lstm_model_round5_f.summary()

# Build LSTM model for Office Supplies category
lstm_model_round5_s = Sequential()
lstm_model_round5_s.add(LSTM(num_neurons5_layer1,
                           input_shape=(X_train5_s.shape[1], 1),
                           return_sequences=True,
                           kernel_regularizer=regularization(regularization_factor)))
lstm_model_round5_s.add(LSTM(num_neurons5_layer2,
                           return_sequences=True,
                           kernel_regularizer=regularization(regularization_factor)))
lstm_model_round5_s.add(LSTM(num_neurons5_layer3,
                           return_sequences=True,
                           kernel_regularizer=regularization(regularization_factor)))
lstm_model_round5_s.add(LSTM(num_neurons5_layer4, kernel_regularizer=regularization(regularization_factor)))
lstm_model_round5_s.add(Dense(1))
lstm_model_round5_s.compile(optimizer='adam', loss='mean_squared_error')
lstm_model_round5_s.summary()

# Build LSTM model for Technology category
lstm_model_round5_t = Sequential()
lstm_model_round5_t.add(LSTM(num_neurons5_layer1,
                           input_shape=(X_train5_t.shape[1], 1),
                           return_sequences=True,
                           kernel_regularizer=regularization(regularization_factor)))
lstm_model_round5_t.add(LSTM(num_neurons5_layer2,
                           return_sequences=True,
                           kernel_regularizer=regularization(regularization_factor)))
lstm_model_round5_t.add(LSTM(num_neurons5_layer3,
                           return_sequences=True,
                           kernel_regularizer=regularization(regularization_factor)))
lstm_model_round5_t.add(LSTM(num_neurons5_layer4, kernel_regularizer=regularization(regularization_factor)))
lstm_model_round5_t.add(Dense(1))
lstm_model_round5_t.compile(optimizer='adam', loss='mean_squared_error')
lstm_model_round5_t.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_8 (LSTM)                   │ (None, 12, 100)        │        40,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_9 (LSTM)                   │ (None, 12, 60)         │        38,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_10 (LSTM)                  │ (None, 12, 30)         │        10,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_11 (LSTM)                  │ (None, 10)             │         1,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 92,011 (359.42 KB)
#  Trainable params: 92,011 (359.42 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_12 (LSTM)                  │ (None, 12, 100)        │        40,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_13 (LSTM)                  │ (None, 12, 60)         │        38,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_14 (LSTM)                  │ (None, 12, 30)         │        10,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_15 (LSTM)                  │ (None, 10)             │         1,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 92,011 (359.42 KB)
#  Trainable params: 92,011 (359.42 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_16 (LSTM)                  │ (None, 12, 100)        │        40,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_17 (LSTM)                  │ (None, 12, 60)         │        38,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_18 (LSTM)                  │ (None, 12, 30)         │        10,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_19 (LSTM)                  │ (None, 10)             │         1,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 92,011 (359.42 KB)
#  Trainable params: 92,011 (359.42 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Training

# %%
# Train the model
epochs5 = 300
batch_size5 = 12
early_stopping_patience5 = 20
early_stopping5 = EarlyStopping(monitor='val_loss', mode='min', patience=early_stopping_patience5, restore_best_weights=True, verbose=1)

history5_f = lstm_model_round5_f.fit(X_train5_f, y_train5_f,
                                 epochs=epochs5,
                                 batch_size=batch_size5,
                                 validation_data=(X_validate5_f, y_validate5_f),
                                 callbacks=[early_stopping5],
                                 verbose=1)
# Out:
# Epoch 1/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 834ms/step - loss: 2.6675 - val_loss: 2.6545
# Epoch 2/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 2.5336 - val_loss: 2.5198
# Epoch 3/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 2.4250 - val_loss: 2.3939
# Epoch 4/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 2.3116 - val_loss: 2.2843
# Epoch 5/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 2.2266 - val_loss: 2.1954
# Epoch 6/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 2.1536 - val_loss: 2.1141
# Epoch 7/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 2.0699 - val_loss: 2.0354
# Epoch 8/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 1.9846 - val_loss: 1.9648
# Epoch 9/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 1.9034 - val_loss: 1.8993
# Epoch 10/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 1.8369 - val_loss: 1.8357
# Epoch 11/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 1.7661 - val_loss: 1.7715
# Epoch 12/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 1.6997 - val_loss: 1.7055
# Epoch 13/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 1.6370 - val_loss: 1.6387
# Epoch 14/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 1.5717 - val_loss: 1.5737
# Epoch 15/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.5015 - val_loss: 1.5105
# Epoch 16/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 1.4445 - val_loss: 1.4489
# Epoch 17/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.3909 - val_loss: 1.3906
# Epoch 18/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 1.3358 - val_loss: 1.3366
# Epoch 19/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.2815 - val_loss: 1.2862
# Epoch 20/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 1.2323 - val_loss: 1.2380
# Epoch 21/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 1.1837 - val_loss: 1.1916
# Epoch 22/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 1.1333 - val_loss: 1.1468
# Epoch 23/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 1.0875 - val_loss: 1.1029
# Epoch 24/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 1.0513 - val_loss: 1.0606
# Epoch 25/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - loss: 1.0071 - val_loss: 1.0208
# Epoch 26/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 0.9653 - val_loss: 0.9830
# Epoch 27/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.9240 - val_loss: 0.9471
# Epoch 28/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.8894 - val_loss: 0.9108
# Epoch 29/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.8553 - val_loss: 0.8759
# Epoch 30/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.8265 - val_loss: 0.8437
# Epoch 31/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.7899 - val_loss: 0.8138
# Epoch 32/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.7604 - val_loss: 0.7841
# Epoch 33/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.7286 - val_loss: 0.7555
# Epoch 34/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.7031 - val_loss: 0.7283
# Epoch 35/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.6694 - val_loss: 0.7008
# Epoch 36/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.6434 - val_loss: 0.6724
# Epoch 37/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.6218 - val_loss: 0.6467
# Epoch 38/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.5991 - val_loss: 0.6240
# Epoch 39/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.5764 - val_loss: 0.6031
# Epoch 40/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.5513 - val_loss: 0.5819
# Epoch 41/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.5316 - val_loss: 0.5623
# Epoch 42/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.5084 - val_loss: 0.5425
# Epoch 43/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.4908 - val_loss: 0.5186
# Epoch 44/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.4699 - val_loss: 0.4975
# Epoch 45/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 0.4526 - val_loss: 0.4787
# Epoch 46/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.4323 - val_loss: 0.4663
# Epoch 47/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.4153 - val_loss: 0.4588
# Epoch 48/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.4028 - val_loss: 0.4472
# Epoch 49/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.3864 - val_loss: 0.4204
# Epoch 50/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.3671 - val_loss: 0.3971
# Epoch 51/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.3585 - val_loss: 0.3842
# Epoch 52/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.3430 - val_loss: 0.3736
# Epoch 53/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.3307 - val_loss: 0.3773
# Epoch 54/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.3236 - val_loss: 0.3644
# Epoch 55/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.3097 - val_loss: 0.3413
# Epoch 56/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.2950 - val_loss: 0.3237
# Epoch 57/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.2845 - val_loss: 0.3143
# Epoch 58/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.2766 - val_loss: 0.3039
# Epoch 59/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.2641 - val_loss: 0.2985
# Epoch 60/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.2546 - val_loss: 0.2946
# Epoch 61/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.2467 - val_loss: 0.2861
# Epoch 62/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.2386 - val_loss: 0.2729
# Epoch 63/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.2282 - val_loss: 0.2595
# Epoch 64/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0
300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.0117 - val_loss: 0.0525
# Epoch 235/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 0.0102 - val_loss: 0.0540
# Epoch 236/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 0.0107 - val_loss: 0.0534
# Epoch 237/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.0115 - val_loss: 0.0521
# Epoch 238/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.0108 - val_loss: 0.0529
# Epoch 239/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0109 - val_loss: 0.0521
# Epoch 240/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0097 - val_loss: 0.0509
# Epoch 241/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - loss: 0.0112 - val_loss: 0.0522
# Epoch 242/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 336ms/step - loss: 0.0107 - val_loss: 0.0539
# Epoch 243/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 0.0108 - val_loss: 0.0530
# Epoch 244/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0097 - val_loss: 0.0515
# Epoch 245/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0107 - val_loss: 0.0532
# Epoch 246/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - loss: 0.0115 - val_loss: 0.0583
# Epoch 247/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0112 - val_loss: 0.0562
# Epoch 248/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0111 - val_loss: 0.0529
# Epoch 249/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0108 - val_loss: 0.0524
# Epoch 249: early stopping
# Restoring model weights from the end of the best epoch: 229.

# %%
history5_s = lstm_model_round5_s.fit(X_train5_s, y_train5_s,
                                 epochs=epochs5,
                                 batch_size=batch_size5,
                                 validation_data=(X_validate5_s, y_validate5_s),
                                 callbacks=[early_stopping5],
                                 verbose=1)
# Out:
# Epoch 1/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 873ms/step - loss: 2.6277 - val_loss: 2.6343
# Epoch 2/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 2.5006 - val_loss: 2.5050
# Epoch 3/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 2.4032 - val_loss: 2.3819
# Epoch 4/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 2.2963 - val_loss: 2.2689
# Epoch 5/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 2.1984 - val_loss: 2.1662
# Epoch 6/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 2.1097 - val_loss: 2.0740
# Epoch 7/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 2.0325 - val_loss: 1.9923
# Epoch 8/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 1.9526 - val_loss: 1.9188
# Epoch 9/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 1.8776 - val_loss: 1.8523
# Epoch 10/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 1.8020 - val_loss: 1.7872
# Epoch 11/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 1.7299 - val_loss: 1.7218
# Epoch 12/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 1.6618 - val_loss: 1.6572
# Epoch 13/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - loss: 1.5940 - val_loss: 1.5935
# Epoch 14/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 1.5316 - val_loss: 1.5307
# Epoch 15/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 1.4692 - val_loss: 1.4683
# Epoch 16/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 1.4117 - val_loss: 1.4076
# Epoch 17/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.3518 - val_loss: 1.3508
# Epoch 18/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 1.2974 - val_loss: 1.2971
# Epoch 19/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 1.2447 - val_loss: 1.2453
# Epoch 20/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 1.1966 - val_loss: 1.1980
# Epoch 21/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 1.1486 - val_loss: 1.1526
# Epoch 22/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 1.0990 - val_loss: 1.1104
# Epoch 23/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 1.0568 - val_loss: 1.0706
# Epoch 24/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 1.0130 - val_loss: 1.0299
# Epoch 25/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.9708 - val_loss: 0.9903
# Epoch 26/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.9330 - val_loss: 0.9512
# Epoch 27/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.8964 - val_loss: 0.9131
# Epoch 28/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.8596 - val_loss: 0.8783
# Epoch 29/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.8241 - val_loss: 0.8462
# Epoch 30/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.7927 - val_loss: 0.8154
# Epoch 31/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.7591 - val_loss: 0.7855
# Epoch 32/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.7303 - val_loss: 0.7542
# Epoch 33/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.6998 - val_loss: 0.7246
# Epoch 34/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.6720 - val_loss: 0.6977
# Epoch 35/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.6424 - val_loss: 0.6703
# Epoch 36/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.6178 - val_loss: 0.6429
# Epoch 37/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.5933 - val_loss: 0.6157
# Epoch 38/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.5697 - val_loss: 0.5916
# Epoch 39/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.5481 - val_loss: 0.5725
# Epoch 40/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.5270 - val_loss: 0.5523
# Epoch 41/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.5057 - val_loss: 0.5331
# Epoch 42/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.4860 - val_loss: 0.5141
# Epoch 43/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.4665 - val_loss: 0.4972
# Epoch 44/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.4471 - val_loss: 0.4824
# Epoch 45/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.4283 - val_loss: 0.4667
# Epoch 46/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.4129 - val_loss: 0.4502
# Epoch 47/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.3955 - val_loss: 0.4327
# Epoch 48/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.3821 - val_loss: 0.4152
# Epoch 49/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.3655 - val_loss: 0.4012
# Epoch 50/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.3531 - val_loss: 0.3865
# Epoch 51/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.3393 - val_loss: 0.3722
# Epoch 52/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.3264 - val_loss: 0.3580
# Epoch 53/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.3139 - val_loss: 0.3473
# Epoch 54/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0
# Epoch 147/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 0.0239 - val_loss: 0.0759
# Epoch 148/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 0.0253 - val_loss: 0.0766
# Epoch 149/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 0.0248 - val_loss: 0.0797
# Epoch 150/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 0.0245 - val_loss: 0.0772
# Epoch 151/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0237 - val_loss: 0.0697
# Epoch 152/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.0250 - val_loss: 0.0680
# Epoch 153/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0240 - val_loss: 0.0744
# Epoch 154/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0232 - val_loss: 0.0810
# Epoch 155/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0211 - val_loss: 0.0813
# Epoch 156/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0218 - val_loss: 0.0772
# Epoch 157/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0224 - val_loss: 0.0747
# Epoch 158/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0217 - val_loss: 0.0741
# Epoch 159/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0218 - val_loss: 0.0706
# Epoch 160/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0203 - val_loss: 0.0689
# Epoch 161/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0191 - val_loss: 0.0753
# Epoch 162/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0215 - val_loss: 0.0804
# Epoch 163/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0206 - val_loss: 0.0728
# Epoch 164/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0184 - val_loss: 0.0617
# Epoch 165/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0224 - val_loss: 0.0634
# Epoch 166/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0224 - val_loss: 0.0748
# Epoch 167/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.0204 - val_loss: 0.0787
# Epoch 168/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0185 - val_loss: 0.0808
# Epoch 169/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0199 - val_loss: 0.0785
# Epoch 170/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 0.0205 - val_loss: 0.0728
# Epoch 171/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0195 - val_loss: 0.0697
# Epoch 172/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0190 - val_loss: 0.0668
# Epoch 173/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0193 - val_loss: 0.0729
# Epoch 174/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0187 - val_loss: 0.0823
# Epoch 175/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.0196 - val_loss: 0.0801
# Epoch 176/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0174 - val_loss: 0.0655
# Epoch 177/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0198 - val_loss: 0.0568
# Epoch 178/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0194 - val_loss: 0.0678
# Epoch 179/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0162 - val_loss: 0.0904
# Epoch 180/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0219 - val_loss: 0.0949
# Epoch 181/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.0238 - val_loss: 0.0762
# Epoch 182/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0178 - val_loss: 0.0636
# Epoch 183/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0188 - val_loss: 0.0582
# Epoch 184/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.0201 - val_loss: 0.0641
# Epoch 185/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0154 - val_loss: 0.0796
# Epoch 186/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0176 - val_loss: 0.0848
# Epoch 187/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0197 - val_loss: 0.0757
# Epoch 188/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0172 - val_loss: 0.0676
# Epoch 189/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0160 - val_loss: 0.0664
# Epoch 190/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0184 - val_loss: 0.0721
# Epoch 191/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0156 - val_loss: 0.0770
# Epoch 192/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0169 - val_loss: 0.0794
# Epoch 193/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0166 - val_loss: 0.0725
# Epoch 194/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0172 - val_loss: 0.0629
# Epoch 195/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0163 - val_loss: 0.0667
# Epoch 196/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0167 - val_loss: 0.0807
# Epoch 197/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0179 - val_loss: 0.0845
# Epoch 197: early stopping
# Restoring model weights from the end of the best epoch: 177.

# %%
history5_t = lstm_model_round5_t.fit(X_train5_t, y_train5_t,
                                 epochs=epochs5,
                                 batch_size=batch_size5,
                                 validation_data=(X_validate5_t, y_validate5_t),
                                 callbacks=[early_stopping5],
                                 verbose=1)
# Out:
# Epoch 1/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 817ms/step - loss: 2.6741 - val_loss: 2.5970
# Epoch 2/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 2.5588 - val_loss: 2.4687
# Epoch 3/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 2.4464 - val_loss: 2.3545
# Epoch 4/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 2.3287 - val_loss: 2.2543
# Epoch 5/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 2.2477 - val_loss: 2.1661
# Epoch 6/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 2.1678 - val_loss: 2.0842
# Epoch 7/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 2.0830 - val_loss: 2.0035
# Epoch 8/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 2.0023 - val_loss: 1.9272
# Epoch 9/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 1.9247 - val_loss: 1.8562
# Epoch 10/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 1.8473 - val_loss: 1.7878
# Epoch 11/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 1.7794 - val_loss: 1.7205
# Epoch 12/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 1.7041 - val_loss: 1.6543
# Epoch 13/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 1.6442 - val_loss: 1.5894
# Epoch 14/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 1.5694 - val_loss: 1.5260
# Epoch 15/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 1.5149 - val_loss: 1.4634
# Epoch 16/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 1.4527 - val_loss: 1.4036
# Epoch 17/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 1.3968 - val_loss: 1.3466
# Epoch 18/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.3392 - val_loss: 1.2927
# Epoch 19/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 1.2856 - val_loss: 1.2417
# Epoch 20/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 1.2336 - val_loss: 1.1931
# Epoch 21/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 1.1899 - val_loss: 1.1466
# Epoch 22/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 1.1431 - val_loss: 1.1026
# Epoch 23/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 1.0973 - val_loss: 1.0607
# Epoch 24/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 1.0535 - val_loss: 1.0200
# Epoch 25/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 1.0116 - val_loss: 0.9807
# Epoch 26/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.9722 - val_loss: 0.9427
# Epoch 27/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.9288 - val_loss: 0.9063
# Epoch 28/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.8965 - val_loss: 0.8704
# Epoch 29/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.8620 - val_loss: 0.8355
# Epoch 30/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.8201 - val_loss: 0.8023
# Epoch 31/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0
# Epoch 123/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0583 - val_loss: 0.0590
# Epoch 124/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0569 - val_loss: 0.0592
# Epoch 125/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0526 - val_loss: 0.0596
# Epoch 126/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0554 - val_loss: 0.0592
# Epoch 127/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0484 - val_loss: 0.0590
# Epoch 128/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.0524 - val_loss: 0.0579
# Epoch 129/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.0530 - val_loss: 0.0567
# Epoch 130/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0539 - val_loss: 0.0561
# Epoch 131/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0464 - val_loss: 0.0556
# Epoch 132/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.0531 - val_loss: 0.0544
# Epoch 133/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0504 - val_loss: 0.0537
# Epoch 134/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0513 - val_loss: 0.0528
# Epoch 135/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0504 - val_loss: 0.0523
# Epoch 136/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0444 - val_loss: 0.0518
# Epoch 137/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0508 - val_loss: 0.0509
# Epoch 138/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0478 - val_loss: 0.0504
# Epoch 139/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0494 - val_loss: 0.0502
# Epoch 140/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0457 - val_loss: 0.0507
# Epoch 141/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0467 - val_loss: 0.0516
# Epoch 142/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0432 - val_loss: 0.0528
# Epoch 143/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0398 - val_loss: 0.0525
# Epoch 144/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0433 - val_loss: 0.0513
# Epoch 145/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0456 - val_loss: 0.0497
# Epoch 146/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0419 - val_loss: 0.0485
# Epoch 147/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0465 - val_loss: 0.0474
# Epoch 148/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 0.0467 - val_loss: 0.0470
# Epoch 149/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0455 - val_loss: 0.0471
# Epoch 150/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0424 - val_loss: 0.0475
# Epoch 151/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0371 - val_loss: 0.0474
# Epoch 152/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0441 - val_loss: 0.0477
# Epoch 153/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0436 - val_loss: 0.0482
# Epoch 154/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0380 - val_loss: 0.0484
# Epoch 155/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0392 - val_loss: 0.0478
# Epoch 156/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0400 - val_loss: 0.0468
# Epoch 157/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0373 - val_loss: 0.0457
# Epoch 158/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0370 - val_loss: 0.0449
# Epoch 159/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0347 - val_loss: 0.0442
# Epoch 160/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0403 - val_loss: 0.0434
# Epoch 161/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0418 - val_loss: 0.0429
# Epoch 162/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0340 - val_loss: 0.0431
# Epoch 163/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0425 - val_loss: 0.0432
# Epoch 164/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0433 - val_loss: 0.0434
# Epoch 165/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0392 - val_loss: 0.0438
# Epoch 166/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0403 - val_loss: 0.0441
# Epoch 167/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0381 - val_loss: 0.0450
# Epoch 168/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.0410 - val_loss: 0.0452
# Epoch 169/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.0346 - val_loss: 0.0450
# Epoch 170/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0317 - val_loss: 0.0441
# Epoch 171/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0326 - val_loss: 0.0424
# Epoch 172/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0384 - val_loss: 0.0404
# Epoch 173/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0358 - val_loss: 0.0391
# Epoch 174/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0353 - val_loss: 0.0379
# Epoch 175/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0408 - val_loss: 0.0373
# Epoch 176/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0394 - val_loss: 0.0377
# Epoch 177/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0374 - val_loss: 0.0391
# Epoch 178/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0357 - val_loss: 0.0405
# Epoch 179/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0376 - val_loss: 0.0409
# Epoch 180/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0380 - val_loss: 0.0414
# Epoch 181/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0392 - val_loss: 0.0421
# Epoch 182/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0385 - val_loss: 0.0424
# Epoch 183/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0367 - val_loss: 0.0425
# Epoch 184/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0335 - val_loss: 0.0422
# Epoch 185/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0358 - val_loss: 0.0416
# Epoch 186/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0392 - val_loss: 0.0408
# Epoch 187/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.0368 - val_loss: 0.0407
# Epoch 188/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0361 - val_loss: 0.0409
# Epoch 189/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.0341 - val_loss: 0.0410
# Epoch 190/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 0.0309 - val_loss: 0.0407
# Epoch 191/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0352 - val_loss: 0.0396
# Epoch 192/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0380 - val_loss: 0.0384
# Epoch 193/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 0.0360 - val_loss: 0.0381
# Epoch 194/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 0.0336 - val_loss: 0.0387
# Epoch 195/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0337 - val_loss: 0.0393
# Epoch 195: early stopping
# Restoring model weights from the end of the best epoch: 175.

# %%
# Plot training and validation loss graphs, one for each category
plot_training_validation_loss(history5_f, '5', 'Exp5: Training and Validation Loss - Furniture')
plot_training_validation_loss(history5_s, '5', 'Exp5: Training and Validation Loss - Office Supplies')
plot_training_validation_loss(history5_t, '5', 'Exp5: Training and Validation Loss - Technology')

# %%
# Predict Sales on TEST Data, for each category: Furniture, Office Supplies, Technology

p_sales_test5_f, y_sales_test5_f, rmse_test5_f = predict_sales(lstm_model_round5_f, X_test5_f, y_test5_f, minMaxScaler5_f)
print(f'Exp5: RMSE score on TEST Data - Furniture: {rmse_test5_f}')

p_sales_test5_s, y_sales_test5_s, rmse_test5_s = predict_sales(lstm_model_round5_s, X_test5_s, y_test5_s, minMaxScaler5_s)
print(f'Exp5: RMSE score on TEST Data - Office Supplies: {rmse_test5_s}')

p_sales_test5_t, y_sales_test5_t, rmse_test5_t = predict_sales(lstm_model_round5_t, X_test5_t, y_test5_t, minMaxScaler5_t)
print(f'Exp5: RMSE score on TEST Data - Technology: {rmse_test5_t}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 586ms/step
# Exp5: RMSE score on TEST Data - Furniture: 59.909787464309154
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 539ms/step
# Exp5: RMSE score on TEST Data - Office Supplies: 101.2922931271511
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 534ms/step
# Exp5: RMSE score on TEST Data - Technology: 126.71924046652569

# %%
# Plot the results of prediction on TEST data, for each category
plot_testing_time_series_lstm(df_round5_f, 'Order Date', p_sales_test5_f, y_sales_test5_f, test_start,
                         'Exp5: Monthly Sales Forecasting using LSTM on TEST Data(Furniture)',
                              mdates.MonthLocator(), mdates.DateFormatter('%b %Y'), 45)


plot_testing_time_series_lstm(df_round5_s, 'Order Date', p_sales_test5_s, y_sales_test5_s, test_start,
                         'Exp5: Monthly Sales Forecasting using LSTM on TEST Data(Office Supplies)',
                              mdates.MonthLocator(), mdates.DateFormatter('%b %Y'), 45)


plot_testing_time_series_lstm(df_round5_t, 'Order Date', p_sales_test5_t, y_sales_test5_t, test_start,
                         'Exp5: Monthly Sales Forecasting using LSTM on TEST Data(Technology)',
                              mdates.MonthLocator(), mdates.DateFormatter('%b %Y'), 45)

# %% [markdown]
# Experienment design 6: Enhanced Architecture & Hyperparameter Optimization​
#
# ​​Modeling & Evaluation - Round 6: Architecture & Hyperparameter Exploration​​
# ​​Network Architecture:​​
#
# ​​5 LSTM Layers​​ with descending neurons: ​​200 → 150 → 75 → 30 → 10​​
# ​​1 Dense Output Layer​​
# ​​Hyperparameter Variations:​​
#
# ​​Window Sizes:​​ Test ​​3-month​​ and ​​12-month​​ lookbacks
# ​​Optimizer:​​ Adam with different ​​learning rates​​ (e.g., 0.001, 0.0005, 0.0001)
# ​​Loss Function:​​ MSE
# ​​Regularization:​​
# ​​L1 (λ = 0.01)​​
# ​​L2 (λ = 0.05)​​
# ​​L2 (λ = 0.001)​​
# ​​Training:​​
# ​​Epochs:​​ 300
# ​​Early Stopping Patience:​​ 20

# %%
#For detailed explanation of the steps, see detailed comments on code cells in Round 1
df_round6 = df[['Order Date', 'Sales']]
df_round6 = df_round6.rename(columns={'Order Date': 'date', 'Sales': 'monthly_sales'})
df_round6.set_index('date', inplace = True)

# %%
# Group by monthly sales
df_round6 = df_round6.resample('ME')['monthly_sales'].sum().reset_index()

# %%
minMaxScaler6 = MinMaxScaler()
df_round6['monthly_sales'] = minMaxScaler6.fit_transform(df_round6[['monthly_sales']])

window = 12 #3
X6, y6 = create_sequences_for_lstm(df_round6['monthly_sales'], window)

# %%
# Split data into training, validation, and testing by the dates specified earlier.
X_train6, y_train6, X_validate6, y_validate6, X_test6, y_test6 = split(df_round6['date'], X6, y6, train_start, train_end, validate_start, validate_end, test_start, test_end, window)

# reshape the input arrays
X_train6, X_validate6, X_test6 = reshape(X_train6, X_validate6, X_test6)

# %%
lstm_model_round6 = Sequential([
    LSTM(128, return_sequences=True, kernel_regularizer=l2(0.005), input_shape=(12, 1)),
    Dropout(0.2),
    LSTM(64, return_sequences=True, kernel_regularizer=l2(0.005)),
    Dropout(0.2),
    LSTM(32, return_sequences=True, kernel_regularizer=l2(0.005)),
    Dropout(0.2),
    LSTM(16, return_sequences=True, kernel_regularizer=l2(0.005)),
    Dropout(0.2),
    LSTM(8, return_sequences=False, kernel_regularizer=l2(0.005)),
    Dense(4, activation='relu'),
    Dense(1)
])
lstm_model_round6.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Train the model
epochs6 = 300
batch_size6 = 12 #3 # 24
early_stopping_patience6 = 20
early_stopping6 = EarlyStopping(monitor='val_loss', mode='min', patience=early_stopping_patience6, restore_best_weights=True, verbose=1)

history6 = lstm_model_round6.fit(X_train6, y_train6,
                                 epochs=epochs6,
                                 batch_size=batch_size6,
                                 validation_data=(X_validate6, y_validate6),
                                 callbacks=[early_stopping6],
                                 verbose=1)
# Out:
# Epoch 1/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 1.7166 - val_loss: 1.7156
# Epoch 2/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 1.6371 - val_loss: 1.6166
# Epoch 3/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 1.5509 - val_loss: 1.5225
# Epoch 4/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 1.4742 - val_loss: 1.4389
# Epoch 5/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 1.4135 - val_loss: 1.3735
# Epoch 6/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 1.3607 - val_loss: 1.3199
# Epoch 7/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 1.3104 - val_loss: 1.2706
# Epoch 8/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 1.2564 - val_loss: 1.2253
# Epoch 9/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 1.2076 - val_loss: 1.1845
# Epoch 10/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 1.1620 - val_loss: 1.1454
# Epoch 11/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 1.1162 - val_loss: 1.1058
# Epoch 12/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 1.0765 - val_loss: 1.0657
# Epoch 13/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 1.0345 - val_loss: 1.0258
# Epoch 14/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.9917 - val_loss: 0.9857
# Epoch 15/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.9529 - val_loss: 0.9462
# Epoch 16/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.9147 - val_loss: 0.9068
# Epoch 17/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.8852 - val_loss: 0.8692
# Epoch 18/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.8433 - val_loss: 0.8344
# Epoch 19/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.8108 - val_loss: 0.8008
# Epoch 20/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.7841 - val_loss: 0.7700
# Epoch 21/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.7508 - val_loss: 0.7419
# Epoch 22/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.7194 - val_loss: 0.7154
# Epoch 23/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.6920 - val_loss: 0.6900
# Epoch 24/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.6677 - val_loss: 0.6649
# Epoch 25/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.6371 - val_loss: 0.6414
# Epoch 26/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.6138 - val_loss: 0.6180
# Epoch 27/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.5893 - val_loss: 0.5931
# Epoch 28/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.5702 - val_loss: 0.5675
# Epoch 29/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.5505 - val_loss: 0.5441
# Epoch 30/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.5281 - val_loss: 0.5240
# Epoch 31/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.5083 - val_loss: 0.5060
# Epoch 32/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.4887 - val_loss: 0.4896
# Epoch 33/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.4676 - val_loss: 0.4732
# Epoch 34/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.4502 - val_loss: 0.4572
# Epoch 35/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.4345 - val_loss: 0.4415
# Epoch 36/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.4210 - val_loss: 0.4258
# Epoch 37/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.3986 - val_loss: 0.4099
# Epoch 38/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.3869 - val_loss: 0.3927
# Epoch 39/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.3746 - val_loss: 0.3768
# Epoch 40/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.3575 - val_loss: 0.3635
# Epoch 41/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.3445 - val_loss: 0.3514
# Epoch 42/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.3376 - val_loss: 0.3409
# Epoch 43/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.3239 - val_loss: 0.3331
# Epoch 44/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.3150 - val_loss: 0.3251
# Epoch 45/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.3002 - val_loss: 0.3172
# Epoch 46/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.2940 - val_loss: 0.3084
# Epoch 47/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.2804 - val_loss: 0.2998
# Epoch 48/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - loss: 0.2684 - val_loss: 0.2903
# Epoch 49/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 0.2667 - val_loss: 0.2781
# Epoch 50/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.2544 - val_loss: 0.2665
# Epoch 51/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 0.2457 - val_loss: 0.2559
# Epoch 52/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.2370 - val_loss: 0.2467
# Epoch 53/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - loss: 0.2277 - val_loss: 0.2379
# Epoch 54/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.2211 - val_loss: 0.2312
# Epoch 55/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 0.2129 - val_loss: 0.2235
# Epoch 56/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.2083 - val_loss: 0.2172
# Epoch 57/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.
300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.0228 - val_loss: 0.0340
# Epoch 230/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0184 - val_loss: 0.0415
# Epoch 231/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0197 - val_loss: 0.0454
# Epoch 232/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0203 - val_loss: 0.0362
# Epoch 233/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.0161 - val_loss: 0.0316
# Epoch 234/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0207 - val_loss: 0.0314
# Epoch 235/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0201 - val_loss: 0.0330
# Epoch 236/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0163 - val_loss: 0.0371
# Epoch 237/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0181 - val_loss: 0.0373
# Epoch 238/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0190 - val_loss: 0.0354
# Epoch 239/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0165 - val_loss: 0.0325
# Epoch 240/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 0.0193 - val_loss: 0.0320
# Epoch 241/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 0.0206 - val_loss: 0.0349
# Epoch 241: early stopping
# Restoring model weights from the end of the best epoch: 221.

# %%
# Plot training and validation loss graph
plot_training_validation_loss(history6, '6')

# %%
# Predict Sales on TRAINING Data, then on VALIDATION Data, then on TEST Data

p_sales_training6, y_sales_training6, rmse_training6 = predict_sales(lstm_model_round6, X_train6, y_train6, minMaxScaler6)
p_sales_validation6, y_sales_validation6, rmse_validation6 = predict_sales(lstm_model_round6, X_validate6, y_validate6, minMaxScaler6)
p_sales_test6, y_sales_test6, rmse_test6 = predict_sales(lstm_model_round6, X_test6, y_test6, minMaxScaler6)

print()
print(f'Exp6 RMSE score on TRAINING Data: {rmse_training6}')
print(f'Exp6 RMSE score on VALIDATION Data: {rmse_validation6}')
print(f'Exp6 RMSE score on TEST Data: {rmse_test6}')
print()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 723ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#
# Exp6 RMSE score on TRAINING Data: 114.09929868382515
# Exp6 RMSE score on VALIDATION Data: 132.470151663402
# Exp6 RMSE score on TEST Data: 162.45553710641897

# %%
# Plot the results of prediction on TRAINING data and VALIDATION data
title = 'Round6: Sales Forecasting using LSTM on TRAINING  & VALIDATION Data'
plot_training_and_validation_time_series_lstm(df_round6, 'date', 'monthly_sales', p_sales_training6, p_sales_validation6, minMaxScaler6, title)

# %%
# Plot the results of prediction on TEST data
title = 'Round6: Monthly Sales Forecasting with LSTM on TEST Data - with monthly sum and with rich network architecture'
plot_testing_time_series_lstm(df_round6, 'date', p_sales_test6, y_sales_test6, test_start, title, mdates.MonthLocator(), mdates.DateFormatter('%b %Y'), 45)

# %% [markdown]
# This version attempted various hyperparameter settings, with solid RMSE improvements​​—but the result reiterates that ​​forecast accuracy decreases with diminishing returns​​ based on our current dataset.
#
# Key Takeaways:
#
# Limited Accuracy Potential
# Time-series forecasting inherently carries uncertainty due to:
# Unpredictable external factors
# Natural variation in sales patterns
# Slower networks further minimizing mistakes ​​won't make much of a difference​​
# Architecture Adequacy
# The current ​​5-layer LSTM​​ is sufficiently deep
# Adding layers/additional complexity would be at risk of ​​overfitting without material gains​​
# Future Directions
# Shift focus from architecture tweaks to
# ​​Feature engineering​​ (e.g., external regressors like promotions, holidays)
# ​​Alternative approaches​​ (e.g., ensemble methods, hybrid models)
# Accept that ​​some forecast error is unavoidable​​
# ​​Conclusion:​​
# While hyperparameter tuning provided incremental gains, ​​diminishing returns suggest we’ve reached the dataset’s predictive limits​​ with this architecture. Future efforts should explore complementary strategies rather than deeper networks.
